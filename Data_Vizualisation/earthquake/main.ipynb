# %%
# %load_ext autoreload
# %autoreload 2
from config import DISASTER_SETTINGS
from data_engine import load_disaster_data
from exporter import export_dashboard_html

# ==========================================
# 🔴 THE FLIP SWITCH: Activate Live USGS Data
# ==========================================
USE_REAL_DATA = False


# ==========================================

disaster = 'earthquake'
config = DISASTER_SETTINGS[disaster]

# This will now trigger the API fetch!
df = load_disaster_data(disaster, use_real_data=USE_REAL_DATA)

filename = f"{disaster}_dashboard.html"
export_dashboard_html(df, config, filename)
print("\n✅ Live Dashboard Ready!")
# Out:
# Failed to read module file 'c:\Users\Ayaan\Desktop\Plotly-Dash\ResQfy-Data\v5-earthquakes - Copy\exporter.py' for module 'exporter': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\Ayaan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 556, in maybe_reload_module
#     new_source_code = f.read()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 446: character maps to <undefined>
# Failed to read module file 'c:\Users\Ayaan\Desktop\Plotly-Dash\ResQfy-Data\v5-earthquakes - Copy\exporter.py' for module 'exporter': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\Ayaan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 446: character maps to <undefined>
# Failed to read module file 'c:\Users\Ayaan\Desktop\Plotly-Dash\ResQfy-Data\v5-earthquakes - Copy\data_engine.py' for module 'data_engine': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\Ayaan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 5160: character maps to <undefined>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [DATA] Generating internal SYNTHETIC data for earthquake...
# 📦 Embedded: mountain.glb
# 📦 Embedded: city.glb
# 📦 Embedded: desert.glb
# 📦 Embedded: river.glb
# ✅ STANDALONE READY: earthquake_dashboard.html
#
# ✅ Live Dashboard Ready!
